# %% [markdown]
# # Install
# - Make sure you have installed MTCNN
# `pip instal mtcnn`

# %% [markdown]
# # Usage example

# %%
import cv2
import torch
from mtcnn import MTCNN
from mtcnn.utils.images import load_image

# create a detector instance
detector = MTCNN(device="GPU:0")

# load an image
# image = load_image('dataset/do_mi_xi/do1.jpg')
image = load_image('dataset/many_faces.jpg')

# detect faces in the image
result = detector.detect_faces(image)

print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import cv2
# ----> 2 import torch
#       3 from mtcnn import MTCNN
#       4 from mtcnn.utils.images import load_image
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\__init__.py:2787
#    2783     torch_module_name = ".".join([__name__, device_type])
#    2784     sys.modules[torch_module_name] = module
# -> 2787 from torch import (
#    2788     export as export,
#    2789     func as func,
#    2790     library as library,
#    2791     return_types as return_types,
#    2792 )
#    2793 from torch._higher_order_ops import cond as cond, while_loop as while_loop
#    2794 from torch.func import vmap as vmap
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\export\__init__.py:42
#      39 import torch.export.custom_ops
# ...

# %% [markdown]
# # MTCNN in pytorch

# %%
from facenet_pytorch import MTCNN
import torch
import cv2
from myFunctions.notworlecv2 import read_display_img

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

# Threshold for P, R, O layers
mtcnn = MTCNN(thresholds=[0.7, 0.7, 0.8], keep_all=True, device=device)

image = cv2.imread('../dataset/no_face.jpg')

box, probs = mtcnn.detect(image)
if box is not None:
    for face, prob in zip(box, probs):
        x1, y1, x2, y2 = [int(x) for x in face]
        cv2.rectangle(image, pt1=(x1, y1), pt2=(x2, y2), color=(173, 250, 93), thickness=2)

read_display_img(image)
# Out:
# cuda:0
# Image shape: (414, 736, 3)
# Image dtype: uint8
